# %% [markdown]
# # Diesease Classifications

# %% [markdown]
# ## Import all the dependencies

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
#from IPython.display import HTML
import numpy as np

# %% [markdown]
# ## Set all the constraints

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS = 3
EPOCHS = 50

# %%
dataset= tf.keras.preprocessing.image_dataset_from_directory(
    "Plant_Village", 
    seed= 123,
    shuffle= True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE   
)
# Out:
# Found 2475 files belonging to 2 classes.

# %%
class_names=dataset.class_names
class_names
# Out:
# ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy']

# %%
for image_batch, label_batch in dataset.take(1):
    print(image_batch[0].shape)
    print(label_batch[0].numpy())
# Out:
# (256, 256, 3)
# 1

# %%
plt.figure(figsize=(12,10))

for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %% [markdown]
# ### Function to Split Dataset
# Dataset should be bifurcated into 3 subsets, namely:
#
# 1. Training: Dataset to be used while training
# 2. Validation: Dataset to be tested against while training
# 3. Test: Dataset to be tested against after we trained a model

# %%
len(dataset)
# Out:
# 78

# %%
#training size will be 80% of the datset 10% will be vlidation and rest will be test

train_size = 0.8
len(dataset)*train_size
# Out:
# 62.400000000000006

# %%
train_ds = dataset.take(63)
len(train_ds)
# Out:
# 63

# %%
test_ds = dataset.skip(63)
len(test_ds)
# Out:
# 15

# %%
val_size = 0.1
len(dataset)*0.1
# Out:
# 7.800000000000001

# %%
val_ds= test_ds.take(8)
len(val_ds)
# Out:
# 8

# %%
test_ds = test_ds.skip(8)
len(test_ds)
# Out:
# 7

# %%
def get_dataset_partition(ds, train_split = 0.8, val_split = 0.1, test_split = 0.1, shuffle = True, shuffle_size=1000):
    assert (train_split+val_split+test_split)==1
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(ds_size*train_split)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds,val_ds,test_ds

# %%
train_ds,val_ds,test_ds = get_dataset_partition(dataset)

# %%
len(train_ds),len(val_ds),len(test_ds)
# Out:
# (62, 7, 9)

# %% [markdown]
# # Cache, Shuffle, and Prefetch the Dataset

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ## Biulding the Model

# %%
#resizing and rescaling the image
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1./255),
    ])

# %%
#data augmentation
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 2
models = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32,kernel_size = (3,3), activation='relu',input_shape=input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='sigmoid')
])

models.build(input_shape = input_shape)

# %%
models.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (32, 256, 256, 3)         0
# _________________________________________________________________
# sequential_1 (Sequential)    (32, 256, 256, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (32, 254, 254, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (32, 127, 127, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (32, 125, 125, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (32, 62, 62, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (32, 60, 60, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (32, 30, 30, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (32, 28, 28, 64)          36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (32, 14, 14, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (32, 12544)               0
# _________________________________________________________________
# dense (Dense)                (32, 64)                  802880
# _________________________________________________________________
# dense_1 (Dense)              (32, 2)                   130
# =================================================================
# Total params: 896,258
# Trainable params: 896,258
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compiling the Model

# %%
models.compile(
optimizer= 'adam',
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
metrics=['accuracy'])

# %%
history = models.fit(
train_ds,
batch_size = BATCH_SIZE,
validation_data=val_ds,
    verbose = 1,
    epochs = 50
)
# Out:
# Epoch 1/50
# 62/62 [==============================] - 55s 817ms/step - loss: 0.6949 - accuracy: 0.6205 - val_loss: 0.5432 - val_accuracy: 0.8125
# Epoch 2/50
# 62/62 [==============================] - 46s 734ms/step - loss: 0.4829 - accuracy: 0.7988 - val_loss: 0.9141 - val_accuracy: 0.7946
# Epoch 3/50
# 62/62 [==============================] - 45s 723ms/step - loss: 0.2727 - accuracy: 0.9246 - val_loss: 0.4652 - val_accuracy: 0.9509
# Epoch 4/50
# 62/62 [==============================] - 45s 731ms/step - loss: 0.2148 - accuracy: 0.9358 - val_loss: 0.3020 - val_accuracy: 0.9598
# Epoch 5/50
# 62/62 [==============================] - 49s 797ms/step - loss: 0.1546 - accuracy: 0.9598 - val_loss: 0.1825 - val_accuracy: 0.9688
# Epoch 6/50
# 62/62 [==============================] - 46s 749ms/step - loss: 0.1669 - accuracy: 0.9531 - val_loss: 0.3979 - val_accuracy: 0.8348
# Epoch 7/50
# 62/62 [==============================] - 46s 746ms/step - loss: 0.0789 - accuracy: 0.9740 - val_loss: 0.1221 - val_accuracy: 0.9821
# Epoch 8/50
# 62/62 [==============================] - 46s 745ms/step - loss: 0.0450 - accuracy: 0.9878 - val_loss: 0.1617 - val_accuracy: 0.9643
# Epoch 9/50
# 62/62 [==============================] - 47s 751ms/step - loss: 0.0365 - accuracy: 0.9929 - val_loss: 0.1046 - val_accuracy: 0.9777
# Epoch 10/50
# 62/62 [==============================] - 47s 773ms/step - loss: 0.0242 - accuracy: 0.9944 - val_loss: 0.0824 - val_accuracy: 0.9821
# Epoch 11/50
# 62/62 [==============================] - 46s 742ms/step - loss: 0.1692 - accuracy: 0.9577 - val_loss: 0.2817 - val_accuracy: 0.9464
# Epoch 12/50
# 62/62 [==============================] - 46s 737ms/step - loss: 0.0935 - accuracy: 0.9735 - val_loss: 0.1167 - val_accuracy: 0.9821
# Epoch 13/50
# 62/62 [==============================] - 46s 747ms/step - loss: 0.0626 - accuracy: 0.9852 - val_loss: 0.1296 - val_accuracy: 0.9777
# Epoch 14/50
# 62/62 [==============================] - 46s 742ms/step - loss: 0.0398 - accuracy: 0.9924 - val_loss: 0.0756 - val_accuracy: 0.9911
# Epoch 15/50
# 62/62 [==============================] - 47s 757ms/step - loss: 0.0457 - accuracy: 0.9913 - val_loss: 0.0976 - val_accuracy: 0.9955
# Epoch 16/50
# 62/62 [==============================] - 48s 782ms/step - loss: 0.0277 - accuracy: 0.9934 - val_loss: 0.0888 - val_accuracy: 0.9955
# Epoch 17/50
# 62/62 [==============================] - 47s 754ms/step - loss: 0.0386 - accuracy: 0.9918 - val_loss: 0.0662 - val_accuracy: 0.9866
# Epoch 18/50
# 62/62 [==============================] - 48s 777ms/step - loss: 0.0281 - accuracy: 0.9954 - val_loss: 0.0541 - val_accuracy: 0.9911
# Epoch 19/50
# 62/62 [==============================] - 49s 789ms/step - loss: 0.0184 - accuracy: 0.9939 - val_loss: 0.0678 - val_accuracy: 0.9955
# Epoch 20/50
# 62/62 [==============================] - 48s 777ms/step - loss: 0.0200 - accuracy: 0.9975 - val_loss: 0.0919 - val_accuracy: 0.9866
# Epoch 21/50
# 62/62 [==============================] - 50s 803ms/step - loss: 0.0129 - accuracy: 0.9980 - val_loss: 0.0636 - val_accuracy: 0.9955
# Epoch 22/50
# 62/62 [==============================] - 48s 768ms/step - loss: 0.0201 - accuracy: 0.9934 - val_loss: 0.0590 - val_accuracy: 0.9955
# Epoch 23/50
# 62/62 [==============================] - 47s 755ms/step - loss: 0.0229 - accuracy: 0.9939 - val_loss: 0.0681 - val_accuracy: 0.9821
# Epoch 24/50
# 62/62 [==============================] - 47s 760ms/step - loss: 0.0220 - accuracy: 0.9939 - val_loss: 0.0734 - val_accuracy: 0.9955
# Epoch 25/50
# 62/62 [==============================] - 46s 740ms/step - loss: 0.0285 - accuracy: 0.9929 - val_loss: 0.0491 - val_accuracy: 0.9911
# Epoch 26/50
# 62/62 [==============================] - 44s 716ms/step - loss: 0.0174 - accuracy: 0.9975 - val_loss: 0.0235 - val_accuracy: 0.9955
# Epoch 27/50
# 62/62 [==============================] - 44s 717ms/step - loss: 0.0082 - accuracy: 0.9980 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 28/50
# 62/62 [==============================] - 44s 717ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 29/50
# 62/62 [==============================] - 45s 719ms/step - loss: 0.0164 - accuracy: 0.9939 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 30/50
# 62/62 [==============================] - 44s 716ms/step - loss: 0.0083 - accuracy: 0.9980 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 31/50
# 62/62 [==============================] - 44s 716ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.0108 - val_accuracy: 0.9911
# Epoch 32/50
# 62/62 [==============================] - 44s 717ms/step - loss: 0.0056 - accuracy: 0.9969 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 33/50
# 62/62 [==============================] - 45s 718ms/step - loss: 0.0109 - accuracy: 0.9975 - val_loss: 0.0186 - val_accuracy: 0.9911
# Epoch 34/50
# 62/62 [==============================] - 44s 714ms/step - loss: 0.0991 - accuracy: 0.9786 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 35/50
# 62/62 [==============================] - 44s 722ms/step - loss: 0.0219 - accuracy: 0.9924 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 36/50
# 62/62 [==============================] - 44s 716ms/step - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0097 - val_accuracy: 0.9955
# Epoch 37/50
# 62/62 [==============================] - 44s 716ms/step - loss: 0.0088 - accuracy: 0.9985 - val_loss: 0.0427 - val_accuracy: 0.9777
# Epoch 38/50
# 62/62 [==============================] - 44s 714ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 39/50
# 62/62 [==============================] - 44s 716ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 40/50
# 62/62 [==============================] - 44s 715ms/step - loss: 0.0040 - accuracy: 0.9980 - val_loss: 0.0101 - val_accuracy: 0.9955
# Epoch 41/50
# 62/62 [==============================] - 44s 715ms/step - loss: 0.0129 - accuracy: 0.9959 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 42/50
# 62/62 [==============================] - 44s 715ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 43/50
# 62/62 [==============================] - 45s 723ms/step - loss: 8.8787e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 44/50
# 62/62 [==============================] - 48s 782ms/step - loss: 7.7437e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 45/50
# 62/62 [==============================] - 48s 771ms/step - loss: 8.3719e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9955
# Epoch 46/50
# 62/62 [==============================] - 47s 763ms/step - loss: 0.0030 - accuracy: 0.9985 - val_loss: 0.0350 - val_accuracy: 0.9866
# Epoch 47/50
# 62/62 [==============================] - 47s 761ms/step - loss: 0.0312 - accuracy: 0.9883 - val_loss: 0.0704 - val_accuracy: 0.9955
# Epoch 48/50
# 62/62 [==============================] - 47s 756ms/step - loss: 0.0182 - accuracy: 0.9959 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 49/50
# 62/62 [==============================] - 47s 766ms/step - loss: 0.0087 - accuracy: 0.9980 - val_loss: 0.0119 - val_accuracy: 0.9955
# Epoch 50/50
# 62/62 [==============================] - 48s 773ms/step - loss: 0.0188 - accuracy: 0.9924 - val_loss: 5.5530e-04 - val_accuracy: 1.0000

# %%
scores = models.evaluate(test_ds)
# Out:
# 9/9 [==============================] - 2s 170ms/step - loss: 0.0035 - accuracy: 0.9965

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 50, 'steps': 62}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history.history['loss'][0:10]
# Out:
# [0.6948502659797668,
#  0.48287808895111084,
#  0.2726582884788513,
#  0.2147553414106369,
#  0.1546081155538559,
#  0.16686208546161652,
#  0.07892214506864548,
#  0.044967107474803925,
#  0.03646759316325188,
#  0.024248894304037094]

# %%
history.history['accuracy'][:10]
# Out:
# [0.6204788684844971,
#  0.7987774014472961,
#  0.9246051907539368,
#  0.9358125329017639,
#  0.9597554802894592,
#  0.9531329870223999,
#  0.9740193486213684,
#  0.9877738356590271,
#  0.9928680658340454,
#  0.9943963289260864]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
#plotting the accuracy and losses
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)

plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')

plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Run Prediction on Sample Images

# %%
for image_batch, label_batch in dataset.take(1):
    
    first_image = image_batch[0].numpy().astype('uint8')
    first_label = label_batch[0].numpy()
    
    print("the first image to predict:")
    plt.imshow(first_image)
    print("actual level: ", class_names[first_label])
    
    batch_prediction = models.predict(image_batch)
    
    print("predicted label: ", class_names[np.argmax(batch_prediction[0])])
# Out:
# the first image to predict:
# actual level:  Pepper__bell___Bacterial_spot
# predicted label:  Pepper__bell___Bacterial_spot

# %% [markdown]
# # function for inference

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)
    
    predictions = models.predict(img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(models, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
